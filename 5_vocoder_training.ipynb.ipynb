# %%
# !git clone https://github.com/facebookresearch/speech-resynthesis.git
# %cd /kaggle/working/speech-resynthesis

# %%
# !pip install torch numpy librosa scipy tensorboard soundfile amfm_decompy matplotlib ffmpeg tqdm

# %%
import glob

# %%
# !python -m examples.speech_to_speech_translation.train \
    --checkpoint_path /kaggle/working/speech-resynthesis/checkpoints/lj_hubert100_dur1.0 \
    --config /kaggle/input/in4remodel/hubert100_dw1.0.json \
    --training_epochs 129 \
    --training_steps 500000 \
    --stdout_interval 5 \
    --checkpoint_interval 5000 \
    --summary_interval 100 \
    --validation_interval 5000 \
    --max_checkpoints_to_keep 20 \
    --patience 5
# Out:
# Initializing Training Process..
# DurationCodeGenerator(
#   (conv_pre): Conv1d(128, 512, kernel_size=(7,), stride=(1,), padding=(3,))
#   (ups): ModuleList(
#     (0): ConvTranspose1d(512, 256, kernel_size=(11,), stride=(5,), padding=(3,))
#     (1): ConvTranspose1d(256, 128, kernel_size=(8,), stride=(4,), padding=(2,))
#     (2): ConvTranspose1d(128, 64, kernel_size=(8,), stride=(4,), padding=(2,))
#     (3): ConvTranspose1d(64, 32, kernel_size=(4,), stride=(2,), padding=(1,))
#     (4): ConvTranspose1d(32, 16, kernel_size=(4,), stride=(2,), padding=(1,))
#   )
#   (resblocks): ModuleList(
#     (0): ResBlock1(
#       (convs1): ModuleList(
#         (0): Conv1d(256, 256, kernel_size=(3,), stride=(1,), padding=(1,))
#         (1): Conv1d(256, 256, kernel_size=(3,), stride=(1,), padding=(3,), dilation=(3,))
#         (2): Conv1d(256, 256, kernel_size=(3,), stride=(1,), padding=(5,), dilation=(5,))
#       )
#       (convs2): ModuleList(
# ...
